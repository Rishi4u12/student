# %% [raw]
# ---
# toc: true
# layout: post
# categories: [Python]
# title: Remakers - 3.13 Developing Procedures Python Hacks
# description: "Apply your skills to basic procedure development in Javascript."
# permalink: /python/developing-procedures/remakers-hw
# author: Krishna Visvanath, Sloane Sommers
# ---

# %% [markdown]
# ### Q1 (Easy)
# Which of these procedures is named well, provide a **short** explanation of justification

# %%
def mix_ingredients():

def do_it():

def make_move():

# %% [markdown]
# **Explanation Here:**
# __ is right because..

# %%
**Answer**

- `mix_ingredients` — well named: clearly describes the action and its object.
- `do_it` — poorly named: too vague, gives no clue what it does.
- `make_move` — acceptable but generic: indicates action but could be more specific about the movement.

# %% [markdown]
# ### Q2 (Medium)
# Finish the code to have a correctly named procedure

# %%
def make_left_turn():
    move_forward()
    rotate_180()
    move_forward()

##Todo: add corresponding procedure definitions
##here- replace this line with your code
def move_forward():
    print("Moving forward.")

##here- replace this line with your code
def rotate_180():
    print("Turning left")

##here- replace this line with your code
# The second call to move_forward() will reuse the same procedure above
# and print "Moving forward." again.

# Run the procedure
if __name__ == '__main__':
    make_left_turn()

# %% [markdown]
# ### Q3 (Hard)
# Write code to fulfill the requirements
# Doing a dance! 🕺💃
# Must have
# 1. A shimmy left procedure
# - Print `super cool left slide`
# 2. A shimmy right procedure, print `even cooler right slide`
# 3. Doing a bow to the crowd, print `Great dance!`, `the audience claps at your bow!`

# %%
##Code away!
# def mix_ingredients():
    """Mix the ingredients together."""
    print("Mixing ingredients.")

def do_it():
    """Example implementation for a named procedure; avoid vague names in real code."""
    print("Doing the specified action.")

def make_move():
    """Perform a move; this could be made more specific in a real program."""
    print("Making a move.")
``````python
def shimmy_left():
    print("super cool left slide")

def shimmy_right():
    print("even cooler right slide")

def bow_to_crowd():
    print("Great dance!")
    print("the audience claps at your bow!")

# Demo the dance routine
shimmy_left()
shimmy_right()
bow_to_crowd()
