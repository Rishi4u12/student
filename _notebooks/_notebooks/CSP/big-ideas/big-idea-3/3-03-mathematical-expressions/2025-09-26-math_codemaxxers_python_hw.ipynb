# %% [raw]
# ---
# layout: post
# title: 3.3 Mathematical Expressions - Python HW
# permalink: /csp/math-expressions-python-hw
# categories: [CSP, Big Idea 3]
# description: Practice with mathematical expressions and PEMDAS in Python.
# tags: [python, math, expressions]
# ---

# %% [markdown]
# # Basic Algebraic Math hacks
#
# ## Q1 (Exponents):
# ### A cube has a side length of 4 units. What is its volume?

# %%
# Q1: Evaluate expression using PEMDAS
# Example: (7 + 5) * 2 ** 3 - 10 / 2
result_q1 = (7 + 5) * (2 ** 3) - 10 / 2
print(result_q1)
# Out:
# 91.0

# %% [markdown]
# ## Q2 (PEMDAS):
# ### Evaluate the expression:
#
#  (12+8)/2+(3^2)

# %%
# Q2: Convert word problem to code
# A tank holds 15.75 gallons and leaks 0.25 gal/min for 20 minutes. How much remains?
start = 15.75
leak_rate = 0.25  # gallons per minute
minutes = 20
remaining = start - leak_rate * minutes
print(remaining)  # expected 10.75
# Out:
# 10.75

# %% [markdown]
# ## Q3 (Algorithm):
#
# Write Python  code where you define variables and run commands that find the values of operations you apply onto them

# %%
# Q3: Define variables and show integer vs float division
x, y = 17, 4
print("true_division:", x / y)   # 4.25 (float)
print("floor_division:", x // y)  # 4 (int)
print("modulo:", x % y)           # 1 remainder
# Out:
# true_division: 4.25
# floor_division: 4
# modulo: 1

# %% [markdown]
# <img src="/images/3_3diagram.png" alt="Diagram showing mathematical operations" style="max-width:300px; margin:10px;">
